# %%
import pandas as pd

# %%
# %cd /home/jovyan/work/
# Out:
# /home/jovyan/work

# %%
dataset = pd.read_csv('data/UCI_Credit_Card.csv')

# %%
dataset.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
from katas.decission_tree.kata_tree import DecisionTree

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataset)

# %%
train.shape
# Out:
# (22500, 25)

# %%
test.shape
# Out:
# (7500, 25)

# %%
train.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  22500.000000    22500.000000  22500.000000  22500.000000  22500.000000
# mean   14985.562889   166899.985778      1.601956      1.856533      1.553911
# std     8659.552131   129653.980211      0.489506      0.796144      0.521190
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7511.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    14950.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22461.500000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  22500.000000  22500.000000  22500.000000  22500.000000  22500.000000
# mean      35.496311     -0.014533     -0.127289     -0.161111     -0.214800
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(train[train.columns.drop('default.payment.next.month')], train[['default.payment.next.month']].values)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
clf.score(test[train.columns.drop('default.payment.next.month')], test[['default.payment.next.month']])
# Out:
# 0.818
