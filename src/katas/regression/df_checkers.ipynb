# %% [markdown]
# ### This notebook need to visualisation of the test dataset

# %%
from katas.regression.utils import liner_regression_generator 
import numpy as np

# %%
liner_df = liner_regression_generator.generate_set([-3,3], lambda x:np.sin(x), set_size = 1000)
liner_df.head()
# Out:
#     feature     value
# 0  0.534136  0.401086
# 1  2.621505  0.634832
# 2  1.879981  0.954639
# 3  1.140721  0.937616
# 4  0.612487  0.833889

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.scatter(liner_df['feature'], liner_df['value'])
plt.show()
